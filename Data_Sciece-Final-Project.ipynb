# %% [markdown]
# <div style="border-radius:10px;
#             border : #015a2c solid;
#             background-color:#D7D9DB;
#            font-size:110%;
#            letter-spacing:0.5px;
#             text-align: center">
# ​
# <center><h1 style="padding: 25px 0px; color:#015a4c; font-weight: bold; font-family: Cursive">
# Amit Project for Data Science Module <br><br>💡💡💡💡💡 <br><br> AI Online 74  </h1></center>
# <center><h3 style="padding-bottom: 25px; color:#025b2c; font-weight: bold; font-style:italic; font-family: Cursive">
# Using Project: Trip data Ford go bike  </h3></center>
# ​
# </div>

# %% [markdown]
# # Part I - (Dataset Exploration for Ford GoBike)
#
# ### worked by (Mostafa Abbas Saad/2024 )
#
# ## Introduction
#
# .
#
# > **Let's introduce our dataset:**
#
#
# ======================================
#
# .
#
# **This data set information was produced from `Ford GoBike` System** the information in it talked about individual rides that were made in a bike-sharing system for covering San Francisco Bay area.**
#
# .

# %% [markdown]
# > ## And here are the main exploring questions
#
#
#
#    **==================================================**
#
#
#
# - What is the structure of your dataset?
#
#
# - What are the main interesting features in the dataset?
#
#
# - What features in the dataset supported my investigation for these interesting features?
#
#
#
#
# .
#
# > ### Also here are the investigative questions classified into three types
#
#
#
#    **================================================**
#
#
#
#
# ###  <a href='#011'> Univariate Exploration</a>
#
# - <a href='#1'> 1 ) . What is the distribution of `User type`?</a>
# - <a href='#2'> 2 ) . What is the distribution for the `bike share users on all Trips`?</a>
# - <a href='#3'> 3 ) . What is the distribution for users' `ages`?</a>
# - <a href='#4'> 4 ) . Do the users' ages have `outlier` values?</a>
# - <a href='#5'> 5 ) . What is the distribution for the trip duration in `minutes`? </a>
# - <a href='#6'> 6) . What is the distribution for `member_gender`? </a>
# - <a href='#7'> 7) . What is the distribution for the trip duration in `Hours`?  </a>
#
#
#
#
# ##  <a href='#111'> Bivariate Exploration</a>
#
#
# - <a href='#8'> 8 ) . What the `average duration` of trip for the categories of `user type`? </a>
# - <a href='#9'> 9 ) . How long is the duration of the trip for `each gender` in `minutes`? </a>
# - <a href='#10'> 10 ) . How long is the duration of the trip for each `user_type` in `minutes`?  </a>
# - <a href='#11'> 11 ) . How the user distribution depending on their `Age` and `user_type` ?</a>
# - <a href='#12'>12 ). How the user distribution depending on their `Age` and `member_gender` ?  </a>
#
#
# ##  <a href='#1111'> Multivariate Exploration</a>
#
#
# - <a href='#13'> 13 ) . What is the Correlation between `each` variable in the dataset?</a>
# - <a href='#14'> 14 ) . What is the Correlation between `specific numeric variables` in the dataset?</a>
# - <a href='#15'> 15 ) . What is the  Correlation between `data_stat` variables in the dataset?</a>
#
#
# ##  <a href='#1100'> Conclusions </a>

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Import Libraries</p>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt

import seaborn as sb

# %matplotlib inline

# %%
# Load my dataset using pandas Dataframe

df = pd.read_csv('for_trip.csv')

# %%
# here we make overview in high-level for data shape and composition
# df.head(5)

df.head(5)
# Out:
#    duration_sec start_time end_time  start_station_id  \
# 0         52185    32:10.1  01:56.0              21.0
# 1         42521    53:21.8  42:03.1              23.0
# 2         61854    13:13.2  24:08.1              86.0
# 3         36490    54:26.0  02:36.8             375.0
# 4          1585    54:18.5  20:44.1               7.0
#
#                                  start_station_name  start_station_latitude  \
# 0  Montgomery St BART Station (Market St at 2nd St)               37.789625
# 1                     The Embarcadero at Steuart St               37.791464
# 2                           Market St at Dolores St               37.769305
# 3                           Grove St at Masonic Ave               37.774836
# 4                               Frank H Ogawa Plaza               37.804562
#
#    start_station_longitude  end_station_id  \
# 0              -122.400811            13.0
# 1              -122.391034            81.0
# 2              -122.426826             3.0
# 3              -122.446546            70.0
# 4              -122.271738           222.0
#
#                                end_station_name  end_station_latitude  \
# 0                Commercial St at Montgomery St             37.794231
# 1                            Berry St at 4th St             37.775880
# 2  Powell St BART Station (Market St at 4th St)             37.786375
# 3                        Central Ave at Fell St             37.773311
# 4                         10th Ave at E 15th St             37.792714
#
#    end_station_longitude  bike_id   user_type  member_birth_year  \
# 0            -122.402923     4902    Customer             1984.0
# 1            -122.393170     2535    Customer                NaN
# 2            -122.404904     5905    Customer             1972.0
# 3            -122.444293     6638  Subscriber             1989.0
# 4            -122.248780     4898  Subscriber             1974.0
#
#   member_gender bike_share_for_all_trip
# 0          Male                      No
# 1           NaN                      No
# 2          Male                      No
# 3         Other                      No
# 4          Male                     Yes

# %%
## check each var  datatype 
df.dtypes
# Out:
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_station_id           float64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_station_id             float64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# bike_id                      int64
# user_type                   object
# member_birth_year          float64
# member_gender               object
# bike_share_for_all_trip     object
# dtype: object

# %%
## I display 15 rows to understand the content values more 
df.head(15)
# Out:
#     duration_sec start_time end_time  start_station_id  \
# 0          52185    32:10.1  01:56.0              21.0
# 1          42521    53:21.8  42:03.1              23.0
# 2          61854    13:13.2  24:08.1              86.0
# 3          36490    54:26.0  02:36.8             375.0
# 4           1585    54:18.5  20:44.1               7.0
# 5           1793    49:58.6  19:51.8              93.0
# 6           1147    55:35.1  14:42.6             300.0
# 7           1615    41:06.8  08:02.8              10.0
# 8           1570    41:48.8  07:59.7              10.0
# 9           1049    49:47.7  07:17.0              19.0
# 10           458    57:57.2  05:35.4             370.0
# 11           506    56:55.5  05:21.7              44.0
# 12          1176    45:12.7  04:49.2             127.0
# 13           915    49:06.1  04:21.9             252.0
# 14           395    56:26.8  03:01.9             243.0
#
#                                    start_station_name  start_station_latitude  \
# 0    Montgomery St BART Station (Market St at 2nd St)               37.789625
# 1                       The Embarcadero at Steuart St               37.791464
# 2                             Market St at Dolores St               37.769305
# 3                             Grove St at Masonic Ave               37.774836
# 4                                 Frank H Ogawa Plaza               37.804562
# 5                        4th St at Mission Bay Blvd S               37.770407
# 6                                Palm St at Willow St               37.317298
# 7                          Washington St at Kearny St               37.795393
# 8                          Washington St at Kearny St               37.795393
# 9                                Post St at Kearny St               37.788975
# 10                                Jones St at Post St               37.787327
# 11  Civic Center/UN Plaza BART Station (Market St ...               37.781074
# 12                             Valencia St at 21st St               37.756708
# 13                       Channing Way at Shattuck Ave               37.865847
# 14                        Bancroft Way at College Ave               37.869360
#
#     start_station_longitude  end_station_id  \
# 0               -122.400811            13.0
# 1               -122.391034            81.0
# 2               -122.426826             3.0
# 3               -122.446546            70.0
# 4               -122.271738           222.0
# 5               -122.391198           323.0
# 6               -121.884995           312.0
# 7               -122.404770           127.0
# 8               -122.404770           127.0
# 9               -122.403452           121.0
# 10              -122.413278            43.0
# 11              -122.411738           343.0
# 12              -122.421025           323.0
# 13              -122.267443           244.0
# 14              -122.254337           252.0
#
#                                      end_station_name  end_station_latitude  \
# 0                      Commercial St at Montgomery St             37.794231
# 1                                  Berry St at 4th St             37.775880
# 2        Powell St BART Station (Market St at 4th St)             37.786375
# 3                              Central Ave at Fell St             37.773311
# 4                               10th Ave at E 15th St             37.792714
# 5                                  Broadway at Kearny             37.798014
# 6                            San Jose Diridon Station             37.329732
# 7                              Valencia St at 21st St             37.756708
# 8                              Valencia St at 21st St             37.756708
# 9                                  Mission Playground             37.759210
# 10  San Francisco Public Library (Grove St at Hyde...             37.778768
# 11                                Bryant St at 2nd St             37.783172
# 12                                 Broadway at Kearny             37.798014
# 13                         Shattuck Ave at Hearst Ave             37.873676
# 14                       Channing Way at Shattuck Ave             37.865847
#
#     end_station_longitude  bike_id   user_type  member_birth_year  \
# 0             -122.402923     4902    Customer             1984.0
# 1             -122.393170     2535    Customer                NaN
# 2             -122.404904     5905    Customer             1972.0
# 3             -122.444293     6638  Subscriber             1989.0
# 4             -122.248780     4898  Subscriber             1974.0
# 5             -122.405950     5200  Subscriber             1959.0
# 6             -121.901782     3803  Subscriber             1983.0
# 7             -122.421025     6329  Subscriber             1989.0
# 8             -122.421025     6548  Subscriber             1988.0
# 9             -122.421339     6488  Subscriber             1992.0
# 10            -122.415929     5318  Subscriber             1996.0
# 11            -122.393572     5848  Subscriber             1993.0
# 12            -122.405950     5328    Customer             1990.0
# 13            -122.268487     5101  Subscriber                NaN
# 14            -122.267443     4786  Subscriber             1988.0
#
#    member_gender bike_share_for_all_trip
# 0           Male                      No
# 1            NaN                      No
# 2           Male                      No
# 3          Other                      No
# 4           Male                     Yes
# 5           Male                      No
# 6         Female                      No
# 7           Male                      No
# 8          Other                      No
# 9           Male                      No
# 10        Female                     Yes
# 11          Male                      No
# 12          Male                      No
# 13           NaN                      No
# 14          Male                      No

# %%
# descriptive statistics for numeric variables
df.describe(include=[float, int])
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  183416.000000     183219.000000           183416.000000
# mean      726.067311        138.590365               37.771221
# std      1794.371831        111.778938                0.099586
# min        61.000000          3.000000               37.317298
# 25%       325.000000         47.000000               37.770083
# 50%       514.000000        104.000000               37.780760
# 75%       796.000000        239.000000               37.797280
# max     85444.000000        398.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            183416.000000   183219.000000         183416.000000
# mean               -122.352661      136.249401             37.771425
# std                   0.117100      111.514916              0.099494
# min                -122.453705        3.000000             37.317298
# 25%                -122.412408       44.000000             37.770407
# 50%                -122.398285      100.000000             37.781010
# 75%                -122.286533      235.000000             37.797320
# max                -121.874119      398.000000             37.880222
#
#        end_station_longitude        bike_id  member_birth_year
# count          183416.000000  183416.000000      175151.000000
# mean             -122.352247    4472.890260        1984.806504
# std                 0.116677    1664.386068          10.116589
# min              -122.453705      11.000000        1878.000000
# 25%              -122.411726    3777.000000        1980.000000
# 50%              -122.398279    4958.000000        1987.000000
# 75%              -122.288045    5502.000000        1992.000000
# max              -121.874119    6645.000000        2001.000000

# %% [markdown]
# > ### What is the structure of your dataset?
#
#
#
#
#
# - The structure of the dataset contains 16 columns and 183416 rows.
#
#
# - Most variables are Numeric in nature , and here are **dtypes summary :**
#
#         - category(7)
#         - float64 (8)
#         - int64   (1)
#
#
#
#
# > ### What are the main interesting features in the dataset?
#
# - Trip duration, user demographics.
#
#
#  **We got three main feature areas which are :**
#
#
#
#
# - Trip Duration
#
#
#
# - User Demographics
#
#
#
#
# - User Type
#
#
#
#
# > ### What features in the dataset supported my investigation for these interesting features?
#
#
#
# - Trip Duration
#
#
#
# - Age
#
#
#
# - Gender
#
#
#
# - User Type
#
#
#
#
# - Start and End Stations

# %% [markdown]
# ##  More Exploring ideas to begin my investigation

# %%
dtypes = df.dtypes
n_unique = df.nunique()
pd.DataFrame({"Dtypes": dtypes, "N_Unique": n_unique}).T
# Out:
#          duration_sec start_time end_time start_station_id start_station_name  \
# Dtypes          int64     object   object          float64             object
# N_Unique         4752      35783    35767              329                329
#
#          start_station_latitude start_station_longitude end_station_id  \
# Dtypes                  float64                 float64        float64
# N_Unique                    334                     335            329
#
#          end_station_name end_station_latitude end_station_longitude bike_id  \
# Dtypes             object              float64               float64   int64
# N_Unique              329                  335                   335    4646
#
#          user_type member_birth_year member_gender bike_share_for_all_trip
# Dtypes      object           float64        object                  object
# N_Unique         2                75             3                       2

# %%
#This code for describing statistical data ideas in a more organized and readable table
df.describe().T
# Out:
#                             count         mean          std          min  \
# duration_sec             183416.0   726.067311  1794.371831    61.000000
# start_station_id         183219.0   138.590365   111.778938     3.000000
# start_station_latitude   183416.0    37.771221     0.099586    37.317298
# start_station_longitude  183416.0  -122.352661     0.117100  -122.453705
# end_station_id           183219.0   136.249401   111.514916     3.000000
# end_station_latitude     183416.0    37.771425     0.099494    37.317298
# end_station_longitude    183416.0  -122.352247     0.116677  -122.453705
# bike_id                  183416.0  4472.890260  1664.386068    11.000000
# member_birth_year        175151.0  1984.806504    10.116589  1878.000000
#
#                                  25%          50%          75%           max
# duration_sec              325.000000   514.000000   796.000000  85444.000000
# start_station_id           47.000000   104.000000   239.000000    398.000000
# start_station_latitude     37.770083    37.780760    37.797280     37.880222
# start_station_longitude  -122.412408  -122.398285  -122.286533   -121.874119
# end_station_id             44.000000   100.000000   235.000000    398.000000
# end_station_latitude       37.770407    37.781010    37.797320     37.880222
# end_station_longitude    -122.411726  -122.398279  -122.288045   -121.874119
# bike_id                  3777.000000  4958.000000  5502.000000   6645.000000
# member_birth_year        1980.000000  1987.000000  1992.000000   2001.000000

# %%
# display the information about each column

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183416 entries, 0 to 183415
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183416 non-null  int64
#  1   start_time               183416 non-null  object
#  2   end_time                 183416 non-null  object
#  3   start_station_id         183219 non-null  float64
#  4   start_station_name       183219 non-null  object
#  5   start_station_latitude   183416 non-null  float64
#  6   start_station_longitude  183416 non-null  float64
#  7   end_station_id           183219 non-null  float64
#  8   end_station_name         183219 non-null  object
#  9   end_station_latitude     183416 non-null  float64
#  10  end_station_longitude    183416 non-null  float64
#  11  bike_id                  183416 non-null  int64
#  12  user_type                183416 non-null  object
#  13  member_birth_year        175151 non-null  float64
#  14  member_gender            175151 non-null  object
#  15  bike_share_for_all_trip  183416 non-null  object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 22.4+ MB

# %%
cat_cols = ['start_station_name', 'end_station_name', 'user_type', 'member_gender', 'bike_share_for_all_trip']
df[cat_cols] = df[cat_cols].astype("category")

# %% [markdown]
# ## <mark>The above result show some missing values exist in some columns So let's display them </mark>

# %%
#yOUR CODES
pd.DataFrame(df.isnull().sum()).T
# Out:
#    duration_sec  start_time  end_time  start_station_id  start_station_name  \
# 0             0           0         0               197                 197
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0                       0                        0             197
#
#    end_station_name  end_station_latitude  end_station_longitude  bike_id  \
# 0               197                     0                      0        0
#
#    user_type  member_birth_year  member_gender  bike_share_for_all_trip
# 0          0               8265           8265                        0

# %% [markdown]
# > ## <mark>The result above shows many missing data </mark>
#
#
#
# ###  To fix this issue You will fill these values with **-Mean-** for numeric and **-Mode-** for categorical

# %%
# trying to fill missing values in my datset using for loop 

numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns

for col in numeric_cols:
    df[col] = df[col].fillna(df[col].mean())

for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183416 entries, 0 to 183415
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183416 non-null  int64
#  1   start_time               183416 non-null  object
#  2   end_time                 183416 non-null  object
#  3   start_station_id         183416 non-null  float64
#  4   start_station_name       183416 non-null  category
#  5   start_station_latitude   183416 non-null  float64
#  6   start_station_longitude  183416 non-null  float64
#  7   end_station_id           183416 non-null  float64
#  8   end_station_name         183416 non-null  category
#  9   end_station_latitude     183416 non-null  float64
#  10  end_station_longitude    183416 non-null  float64
#  11  bike_id                  183416 non-null  int64
#  12  user_type                183416 non-null  category
#  13  member_birth_year        183416 non-null  float64
#  14  member_gender            183416 non-null  category
#  15  bike_share_for_all_trip  183416 non-null  category
# dtypes: category(5), float64(7), int64(2), object(2)
# memory usage: 16.6+ MB

# %%
#check the Nulls 
pd.DataFrame(df.isnull().sum()).T
# Out:
#    duration_sec  start_time  end_time  start_station_id  start_station_name  \
# 0             0           0         0                 0                   0
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0                       0                        0               0
#
#    end_station_name  end_station_latitude  end_station_longitude  bike_id  \
# 0                 0                     0                      0        0
#
#    user_type  member_birth_year  member_gender  bike_share_for_all_trip
# 0          0                  0              0                        0

# %% [markdown]
# ### **And with a proper category for other (member gender)**

# %%
##  still got a missing value in the member_gender, so let's explore this column more 

# print(gbf.member_gender.head(15))
df['member_gender'].head(15)
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3      Other
# 4       Male
# 5       Male
# 6     Female
# 7       Male
# 8      Other
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13      Male
# 14      Male
# Name: member_gender, dtype: category
# Categories (3, object): ['Female', 'Male', 'Other']

# %%
# fill  dataset with missing values.
    
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
for col in numeric_cols:
    df[col] = df[col].fillna(df[col].mean())

categorical_cols = df.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
# print(gbf.member_gender.head(15))
df['member_gender'].head(15)
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3      Other
# 4       Male
# 5       Male
# 6     Female
# 7       Male
# 8      Other
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13      Male
# 14      Male
# Name: member_gender, dtype: category
# Categories (3, object): ['Female', 'Male', 'Other']

# %%
## check my result above 

df['member_gender'].value_counts()
# Out:
# member_gender
# Male      138920
# Female     40844
# Other       3652
# Name: count, dtype: int64

# %% [markdown]
# > ## <mark>The result above shows that we deal with all missing data </mark>

# %% [markdown]
# ### Now let's check duplicate value

# %%
##  check duplicate in dataset
df.duplicated().sum()
# Out:
# np.int64(4)

# %% [markdown]
# > ##If Not significant duplicated , so won't clean it
#
#
# ### Now let's check the category columns to make more cleaning dataset

# %%
### check the category columns that included object
df.select_dtypes(include=['object', 'category']).columns
# Out:
# Index(['start_time', 'end_time', 'start_station_name', 'end_station_name',
#        'user_type', 'member_gender', 'bike_share_for_all_trip'],
#       dtype='object')

# %% [markdown]
#  > ## From all previous results above I found  :
#
#
#
#  **=========================================================**
#
#
#
# > 1 ) **unique Value** as in ((`member_gender`)) : Not significant , so won't clean it
#
#
#
# > 2 ) **Incorrect data type** as in (( `user_type` &&	`member_gender`)) :  significant change , so I need to clean it.
#
#
# > 3 ) **Good factor** for marketing work as in ((`member_birth_year`)) : so I need to clean it.

# %%
##  step  2 ) Incorrect data type as in (( `user_type` &&	`member_gender`)) :  significant change , so  need to clean it.

cat_cols = ['start_station_name', 'end_station_name', 'user_type', 'member_gender', 'bike_share_for_all_trip']
df[cat_cols] = df[cat_cols].astype("category")

# %%
## check your work 
df.dtypes[['user_type', 'member_gender']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183416 entries, 0 to 183415
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183416 non-null  int64
#  1   start_time               183416 non-null  object
#  2   end_time                 183416 non-null  object
#  3   start_station_id         183416 non-null  float64
#  4   start_station_name       183416 non-null  category
#  5   start_station_latitude   183416 non-null  float64
#  6   start_station_longitude  183416 non-null  float64
#  7   end_station_id           183416 non-null  float64
#  8   end_station_name         183416 non-null  category
#  9   end_station_latitude     183416 non-null  float64
#  10  end_station_longitude    183416 non-null  float64
#  11  bike_id                  183416 non-null  int64
#  12  user_type                183416 non-null  category
#  13  member_birth_year        183416 non-null  float64
#  14  member_gender            183416 non-null  category
#  15  bike_share_for_all_trip  183416 non-null  category
# dtypes: category(5), float64(7), int64(2), object(2)
# memory usage: 16.6+ MB

# %%
## step 3 ) Good factor for marketing work as in ((`member_birth_year`)) : so need to clean it.
## To know the target audience's age and serve on them

# create a column for users' age depending on the current year
current_year = pd.to_datetime('today').year

df['age'] = current_year - df['member_birth_year']

# %%
## check your work 

df[['member_birth_year', 'age']].head()
# Out:
#    member_birth_year        age
# 0        1984.000000  40.000000
# 1        1984.806504  39.193496
# 2        1972.000000  52.000000
# 3        1989.000000  35.000000
# 4        1974.000000  50.000000

# %%
## change the new column age data type from float to int
df['age'] = df['age'].astype(int)

# %%
df['age'].dtype
# Out:
# dtype('int64')

# %%
## create a function to know the average users ages
def average_age(df):
    
    avg_age = df['age'].mean()
    return avg_age

avg_age = average_age(df)
print(f"The average age of users is: {avg_age}")
# Out:
# The average age of users is: 39.18477668251407

# %%
## another important factor to offer  marketing services is the trip duration time 

## need to change the time from second to minute to be more usable

df['duration_min'] = df['duration_sec'] / 60

# Check the some values
print(df[['duration_sec', 'duration_min']].head())
# Out:
#    duration_sec  duration_min
# 0         52185    869.750000
# 1         42521    708.683333
# 2         61854   1030.900000
# 3         36490    608.166667
# 4          1585     26.416667

# %%
## I need to change the time from second to Houre  to be more usable
df['duration_hour'] = df['duration_sec'] / 3600

# Check the some values
print(df[['duration_sec', 'duration_hour']].head())
# Out:
#    duration_sec  duration_hour
# 0         52185      14.495833
# 1         42521      11.811389
# 2         61854      17.181667
# 3         36490      10.136111
# 4          1585       0.440278

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Univariate Exploration</p>
# # <a id="011"> Univariate Exploration</a>
#
#
#
# > In this section, investigate distributions of individual variables. If
# you see unusual points or outliers, take a deeper look to clean things up
# and prepare yourself to look at relationships between variables.

# %% [markdown]
# # <a id="1"> 1 ) . What is the distribution for User type?</a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5), dpi=200)
plot = sns.countplot(data=df, x='bike_share_for_all_trip')

plt.xlabel('User distribution')
plt.ylabel('Frequency')
plt.title("Represent the user's distribution depending on being a part of the Trips Program")

plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>

# %% [markdown]
# # <a id="2"> 2 ) What is the distribution for the bike share users on all Trips?</a>

# %% [markdown]
# > ### <mark>Based on the statistical summary of the bike_share_for_all_trip column, the distribution shows a significantly higher number of "No" users compared to "Yes" users. </mark>

# %%
print(df.columns)
# Out:
# Index(['duration_sec', 'start_time', 'end_time', 'start_station_id',
#        'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type',
#        'member_birth_year', 'member_gender', 'bike_share_for_all_trip'],
#       dtype='object')

# %% [markdown]
# # <a id="3"> 3 ) What is the distribution for users' ages? </a>

# %% [markdown]
# > ### <mark>Normal distribution </mark>

# %%
plot = sns.boxplot(x='age', data=df, orient='h')
plt.show()
plt.xlabel("Age")
# Identify outliers using IQR
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['age'] < Q1 - 1.5*IQR) | (df['age'] > Q3 + 1.5*IQR)]
print(outliers)
# Out:
#         duration_sec start_time end_time  start_station_id  \
# 5               1793    49:58.6  19:51.8              93.0
# 43               116    44:01.0  45:57.5             104.0
# 67               681    19:37.4  30:58.9              43.0
# 117              230    01:06.2  04:56.8              73.0
# 152              216    45:22.2  48:58.8             172.0
# ...              ...        ...      ...               ...
# 183296           459    15:05.2  22:44.3             104.0
# 183304           373    42:44.7  48:58.1             131.0
# 183305           100    46:54.8  48:34.8              80.0
# 183385           400    46:47.3  53:27.6             220.0
# 183388           490    39:53.1  48:03.3              61.0
#
#                                        start_station_name  \
# 5                            4th St at Mission Bay Blvd S
# 43                                      4th St at 16th St
# 67      San Francisco Public Library (Grove St at Hyde...
# 117                                Pierce St at Haight St
# 152                               College Ave at Taft Ave
# ...                                                   ...
# 183296                                  4th St at 16th St
# 183304                              22nd St at Dolores St
# 183305                              Townsend St at 5th St
# 183385                        San Pablo Ave at MLK Jr Way
# 183388                                Howard St at 8th St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 5                    37.770407              -122.391198           323.0
# 43                   37.767045              -122.390833            93.0
# 67                   37.778768              -122.415929            70.0
# 117                  37.771793              -122.433708           119.0
# 152                  37.841800              -122.251535           210.0
# ...                        ...                      ...             ...
# 183296               37.767045              -122.390833            30.0
# 183304               37.755000              -122.425728           129.0
# 183305               37.775235              -122.397437            67.0
# 183385               37.811351              -122.273422           337.0
# 183388               37.776513              -122.411306            81.0
#
#                                          end_station_name  \
# 5                                      Broadway at Kearny
# 43                           4th St at Mission Bay Blvd S
# 67                                 Central Ave at Fell St
# 117                                     18th St at Noe St
# 152                                     45th St at Manila
# ...                                                   ...
# 183296     San Francisco Caltrain (Townsend St at 4th St)
# 183304                             Harrison St at 20th St
# 183305  San Francisco Caltrain Station 2  (Townsend St...
# 183385                              Webster St at 19th St
# 183388                                 Berry St at 4th St
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 5                  37.798014            -122.405950     5200  Subscriber
# 43                 37.770407            -122.391198      823  Subscriber
# 67                 37.773311            -122.444293     6333  Subscriber
# 117                37.761047            -122.432642     6321  Subscriber
# 152                37.833294            -122.256224     5701  Subscriber
# ...                      ...                    ...      ...         ...
# 183296             37.776598            -122.395282     3446  Subscriber
# 183304             37.758862            -122.412544     5427  Subscriber
# 183305             37.776639            -122.395526     3138  Subscriber
# 183385             37.806970            -122.266588     3487  Subscriber
# 183388             37.775880            -122.393170     5411  Subscriber
#
#         member_birth_year member_gender bike_share_for_all_trip  age  \
# 5                  1959.0          Male                      No   65
# 43                 1959.0          Male                      No   65
# 67                 1959.0          Male                      No   65
# 117                1963.0          Male                      No   61
# 152                1964.0          Male                      No   60
# ...                   ...           ...                     ...  ...
# 183296             1959.0          Male                      No   65
# 183304             1958.0          Male                      No   66
# 183305             1950.0          Male                      No   74
# 183385             1945.0          Male                     Yes   79
# 183388             1927.0          Male                      No   97
#
#         duration_min  duration_hour
# 5          29.883333       0.498056
# 43          1.933333       0.032222
# 67         11.350000       0.189167
# 117         3.833333       0.063889
# 152         3.600000       0.060000
# ...              ...            ...
# 183296      7.650000       0.127500
# 183304      6.216667       0.103611
# 183305      1.666667       0.027778
# 183385      6.666667       0.111111
# 183388      8.166667       0.136111
#
# [9078 rows x 19 columns]

# %% [markdown]
# # <a id="4">  4 ) . Do the users' ages have outlier values?</a>

# %% [markdown]
# > ### <mark>Yes </mark>

# %% [markdown]
# # <a id="5">  5 ) . What is the distribution for the trip duration in minutes? </a>

# %%
## Review the statistic for trip duration in minutes

df['duration_min'].describe()
# Out:
# count    183416.000000
# mean         12.101122
# std          29.906197
# min           1.016667
# 25%           5.416667
# 50%           8.566667
# 75%          13.266667
# max        1424.066667
# Name: duration_min, dtype: float64

# %%
# Make visualization to easy get insight


if 'duration_min' not in df.columns:
    df['duration_min'] = df['duration_sec'] / 60 

plt.figure(figsize=(12, 6))
sns.histplot(df['duration_min'], kde=True, color='teal', bins=50, stat='density')

plt.title("Distribution of Trip Duration in Minutes", fontsize=18)
plt.xlabel("Duration (minutes)", fontsize=14)
plt.ylabel("Density", fontsize=14)

plt.grid(True, linestyle='--', alpha=0.6)

plt.show()

# %% [markdown]
# > ### <mark>The graph shows that most trips are very short (less than 50 minutes), with a steep decline in density as duration increases. A few outliers exist beyond 200 minutes, but the data is heavily skewed toward shorter durations. </mark>

# %% [markdown]
# # <a id="6"> 6 ) . What is the distribution for member_gender?</a>

# %%
# Make visualization to easy get insight
plt.figure(figsize=(8, 6))

sns.countplot(data=df, x='member_gender', palette='Set2')

plt.title("Distribution of Member Gender", fontsize=16)
plt.xlabel("Gender", fontsize=12)
plt.ylabel("Count", fontsize=12)

plt.show()
# Out:
# C:\Users\S\AppData\Local\Temp\ipykernel_22704\4063932884.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='member_gender', palette='Set2')

# %% [markdown]
# > ### <mark>Based on the statistical analysis of the gender distribution, it shows that **-Male-** represent the majority of the user. </mark>

# %% [markdown]
# # <a id="7">    7 )  . What is the distribution for the trip duration in Hours?  </a>

# %%
# Make visualization to easy get insight

if 'duration_hour' not in df.columns:
    df['duration_hour'] = df['duration_min'] / 60  

plt.figure(figsize=(12, 6))
sns.histplot(df['duration_hour'], kde=True, color='orange', bins=50, stat='density')

plt.title("Distribution of Trip Duration in Hours", fontsize=18)
plt.xlabel("Duration (hours)", fontsize=14)
plt.ylabel("Density", fontsize=14)

plt.grid(True, linestyle='--', alpha=0.6)

plt.show()

# %% [markdown]
# > ### <mark>The graph shows that most trips are very short (under 1 hour), with a highly skewed distribution and few longer trips. Outliers exist beyond 5 hours, but short trips dominate the data. </mark>

# %% [markdown]
# ### The variables distribution:
#
#
# > The distribution of duration present that most of the trips were less than 30 minutes ( we can notice that from the minutes and the hour charts )
#
#
# > And the Age distribution is ( left Skewed ) as most users age are  22 - 39
#
#
# > Most users are subscribers, not Customers and  Males as shown in the charts above.
#
#
#
# ### Were there any interesting and outliers
#
#
# - We got Age outliers for for more than 100 .
#
#
#
# - The distribution of duration was strange where the minutes and the hour charts were 30 minutes or less.

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Bivariate Exploration</p>
# # <a id="111"> Bivariate Exploration</a>
#
# Now let's investigate relationships between pairs of variables in our data.

# %% [markdown]
# # <a id="8"> 8) . What the average duration of trip for the categories of user type?</a>

# %%
# Distribution of Age by user types

avg_trip_duration = df.groupby('user_type')['duration_hour'].mean()
print(f"Average Trip Duration by User Type:\n{avg_trip_duration}")
# Out:
# Average Trip Duration by User Type:
# user_type
# Customer      0.397907
# Subscriber    0.177848
# Name: duration_hour, dtype: float64
# C:\Users\S\AppData\Local\Temp\ipykernel_22704\433397200.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_trip_duration = df.groupby('user_type')['duration_hour'].mean()

# %% [markdown]
# # Make visualization to easy get insight

# %%
# Make visualization
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='age', hue='user_type', kde=True, bins=30, palette='viridis', stat='density')
plt.title("Distribution of Age by User Type", fontsize=16)
plt.xlabel("Age", fontsize=12)
plt.ylabel("Density", fontsize=12)

plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
plot = sns.barplot(x='user_type', y='duration_hour', data=df) # x = categorical , y = numerical
plt.show()

# %%
mode_by_category = df.groupby('user_type')['duration_hour'].agg(pd.Series.mode)
mode_by_category
# Out:
# C:\Users\S\AppData\Local\Temp\ipykernel_22704\3174221996.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_by_category = df.groupby('user_type')['duration_hour'].agg(pd.Series.mode)
# user_type
# Customer      0.137500
# Subscriber    0.075556
# Name: duration_hour, dtype: float64

# %% [markdown]
# > ### <mark>The bar chart shows that customers have a higher average trip duration (around 0.4 hours) compared to subscribers (around 0.2 hours). This suggests that customers tend to take longer trips than subscribers. </mark>

# %% [markdown]
# # <a id="9">    9 ) . How long is the duration of the trip for each gender in minutes?  </a>

# %%
# ------------------------Duration distribution by member gender
avg_trip_duration_gender = df.groupby('member_gender')['duration_min'].mean()

print(f"Average Trip Duration by Gender (in minutes):\n{avg_trip_duration_gender}")
# Out:
# Average Trip Duration by Gender (in minutes):
# member_gender
# Female    12.984506
# Male      11.722903
# Other     16.608589
# Name: duration_min, dtype: float64
# C:\Users\S\AppData\Local\Temp\ipykernel_22704\3397412257.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_trip_duration_gender = df.groupby('member_gender')['duration_min'].mean()

# %%
# Make visualization to easy get insight
avg_trip_duration_gender = df.groupby('member_gender')['duration_min'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(data=avg_trip_duration_gender, x='member_gender', y='duration_min', palette='pastel')

plt.title("Average Trip Duration by Gender (in minutes)", fontsize=18)
plt.xlabel("Gender", fontsize=14)
plt.ylabel("Average Duration (minutes)", fontsize=14)


plt.grid(True, linestyle='--', alpha=0.6)

plt.show()
# Out:
# C:\Users\S\AppData\Local\Temp\ipykernel_22704\2882091920.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_trip_duration_gender = df.groupby('member_gender')['duration_min'].mean().reset_index()
# C:\Users\S\AppData\Local\Temp\ipykernel_22704\2882091920.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_trip_duration_gender, x='member_gender', y='duration_min', palette='pastel')

# %% [markdown]
# # Make visualization to easy get insight

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>

# %% [markdown]
# # <a id="10 "> 10 ) . How long is the duration of the trip for each user_type in minutes?  </a>

# %%
df = df.dropna(subset=['duration_min', 'user_type'])
df['user_type'] = df['user_type'].astype('category')

plt.figure(figsize=(10, 6))
sns.boxplot(x='user_type', y='duration_min', data=df, palette='Set1')

plt.title("Trip Duration Distribution by User Type (in Minutes)", fontsize=18, fontweight='bold')
plt.xlabel("User Type", fontsize=14, labelpad=10)
plt.ylabel("Trip Duration (in Minutes)", fontsize=14, labelpad=10)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# C:\Users\S\AppData\Local\Temp\ipykernel_22704\3167946736.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='user_type', y='duration_min', data=df, palette='Set1')

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>

# %% [markdown]
# # <a id="11">  11 ) . How the user distribution depending on their Age and user_type ? </a>

# %%
# Make visualization to easy get insight
df = df.dropna(subset=['age', 'user_type'])
df['user_type'] = df['user_type'].astype('category')

plt.figure(figsize=(10, 6))

sns.boxplot(x='user_type', y='age', data=df, palette='Set2')

plt.title("User Distribution by Age and User Type", fontsize=18, fontweight='bold')
plt.xlabel("User Type", fontsize=14, labelpad=10)
plt.ylabel("Age", fontsize=14, labelpad=10)

plt.xticks(fontsize=12)
plt.yticks(fontsize=1)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# C:\Users\S\AppData\Local\Temp\ipykernel_19556\4153691989.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='user_type', y='age', data=df, palette='Set2')

# %% [markdown]
# > ### <mark>Normal distribution </mark>

# %% [markdown]
# #  <a id="12"> 12 ). How the user distribution depending on their Age and member_gender ?</a>

# %%
# Make visualization to easy get insight
df.dropna(subset=['age', 'member_gender'], inplace=True)
df['member_gender'] = df['member_gender'].astype('category')

plt.figure(figsize=(10, 6))

sns.boxplot(x='member_gender', y='age', data=df, palette='Set1')

plt.title("Age Distribution by Gender", fontsize=18, fontweight='bold')
plt.xlabel("Gender", fontsize=14, labelpad=10)
plt.ylabel("Age", fontsize=14, labelpad=10)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# C:\Users\S\AppData\Local\Temp\ipykernel_22704\1521317635.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='member_gender', y='age', data=df, palette='Set1')

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > ...................
#
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > ....................

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Multivariate Exploration</p>
# # <a id="1111"> Multivariate Exploration </a>
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %%
## check your work
sns.pairplot(df[['age', 'duration_min', 'user_type']], hue='user_type', palette='Set1')

plt.suptitle("Pairplot: Relationships between Age, Trip Duration, and User Type", fontsize=18, fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(12, 6))

sns.violinplot(x='user_type', y='duration_min', hue='member_gender', data=df, split=True, palette='Set1')

plt.title("Distribution of Trip Duration by User Type and Gender", fontsize=18, fontweight='bold')

plt.show()

# %%
corr = df[['age', 'duration_min']].corr()


plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

plt.title("Correlation Matrix between Age and Trip Duration", fontsize=18, fontweight='bold')

plt.show()

# %%
g = sns.FacetGrid(df, col='user_type', row='member_gender', margin_titles=True)
g.map(sns.scatterplot, 'age', 'duration_min', alpha=0.7)

g.fig.suptitle("Relationship between Age and Trip Duration by User Type and Gender", fontsize=18, fontweight='bold')

plt.show()

# %% [markdown]
# # <a id="13">  13 ) . What is the  Correlation between each variable in the dataset?</a>

# %%
# Make visualization to easy get insight
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

corr = df[numerical_columns].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

plt.title("Correlation Matrix for Numerical Variables", fontsize=18, fontweight='bold')

plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
#
# Example usage
# - There is `no Correlation` for any variable with time ( `duration sec /minutes/hours`)

# %% [markdown]
# # <a id="14"> 14 )  .  What is the  Correlation between `specific numeric variables` in the dataset?</a>

# %%
# Make visualization to easy get insight
selected_columns = ['age', 'duration_min', 'user_type']

df['user_type_numeric'] = df['user_type'].map({'Customer': 0, 'Subscriber': 1})

corr_selected = df[['age', 'duration_min', 'user_type_numeric']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_selected, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation between Selected Numeric Variables", fontsize=18, fontweight='bold')

plt.show()

# %% [markdown]
# > ### <mark>Your analsys and exploration here </mark>
#
# Example usage
# - There is `no Correlation` for any variable with time ( `duration sec /minutes`)
#
#
#
#
# -
#
#
#
#
# -

# %% [markdown]
# # <a id="15">  15 ) What is the  Correlation between data_stat variables in the dataset?</a>

# %%
"""""This time I will use heatmap  to explain how Correlation between data_stat variables

in the dataset in more clear and specific percentage"""

# Make visualization to easy get insight

data_stat_columns = ['age', 'duration_min']  
corr_data_stat = df[data_stat_columns].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_data_stat, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation between Data Stat Variables", fontsize=18, fontweight='bold')

plt.show()

# %% [markdown]
# > ### <mark>The above charts show how Correlation between specific numeric variables in the dataset using heatmap plots  </mark>
#
#
#
# **Actually the `heat map`  display the above ideas in clear percentages**
#
#
#
# - There is `no Correlation` for any variable with time ( `duration sec /minutes`)
#
#
#
#
# - There is a `negative  Correlation` between  member_birth_year  and age which normal.
#
#
#
#
# - There is `no significant Correlation` for any variable with `bike_id `

# %% [markdown]
# # <p style="border-radius:15px;border-style:solid;border-color:lightblue;border-width:3px;background-color:lightblue;padding: 20px;font-family:Verdana;color:#D81F26;font-size:30px;text-align: center;">Conclusions</p>
# # <a id="1100"> Conclusions </a>
#
# #example
# - Most users were Male.
#
#
# -
#
# -
#
# -
#
#
#
# ## limitation
# example
# - We got missing data which we fix some of them .
#
# -
